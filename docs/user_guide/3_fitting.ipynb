# %% [markdown]
# # Fitting Models to Data
#
# Here is how it is done

# %%
import gwrefpy as gr

model = gr.Model('small_example.gwref')
model.fits_summary()
# Out:
# Model 'Small Example' loaded from 'small_example.gwref'.
#   ref_well_name obs_well_name        method      rmse  n_points    stderr  \
# 0        45LOGW       12GIPGW  LinRegResult  0.936776        83  0.180541
# 1        46LOGW       13GIPGW  LinRegResult  0.916701        83  0.202107
#
#    confidence_level calibration_start calibration_end time_offset       t_a  \
# 0              0.95        2020-01-01      2020-03-23          0D  1.989319
# 1              0.95        2020-01-01      2020-03-23          0D  1.989319
#
#    pred_const  linreg_slope  linreg_intercept  linreg_rvalue  linreg_pvalue  \
# 0    0.361311      2.724272        -12.039019       0.936776   1.087235e-38
# 1    0.404470      2.790026         -9.660261       0.916701   5.157469e-34
#
#    linreg_stderr
# 0       0.113071
# 1       0.135124

# %% [markdown]
# We can see that this model contains two well pairs that have already been fitted. We can look closer at the fit performance with the `plot_fitmethod`.

# %%
model.plot_fitmethod(plot_separately=True)
# Out:
# ([<Figure size 500x500 with 1 Axes>, <Figure size 500x500 with 1 Axes>],
#  [<Axes: title={'center': 'Fit Method Plot'}, xlabel='Hydraulic Head Reference Well', ylabel='Hydraulic Head Observation Well'>,
#   <Axes: title={'center': 'Fit Method Plot'}, xlabel='Hydraulic Head Reference Well', ylabel='Hydraulic Head Observation Well'>])
