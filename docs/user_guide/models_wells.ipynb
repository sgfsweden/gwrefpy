# %% [markdown]
# # Models and Wells
#
# Models and wells are important.
#
# ## Models
#
# A model is typically a representation of a site or area of interest. Models can be made up of any number of wells.
